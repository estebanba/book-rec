# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/world_real_estate_data(147k).csv")
df
# Out:
#                                                     title   country  \
# 0       2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1                   4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2               1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3                  1 room apartment  in Pattaya, Thailand  Thailand
# 4                  2 room apartment  in Pattaya, Thailand  Thailand
# ...                                                   ...       ...
# 147531        5 room apartment 310 m² in Gazipasa, Turkey    Turkey
# 147532  4 room apartment 192 m² in Marmara Region, Turkey    Turkey
# 147533        2 room apartment  in Marmara Region, Turkey    Turkey
# 147534                       Apartment  in Akarca, Turkey    Turkey
# 147535                 4 room apartment 140 m² in, Turkey    Turkey
#
#                                          location  building_construction_year  \
# ...

# %%
df.dtypes
# Out:
# title                          object
# country                        object
# location                       object
# building_construction_year    float64
# building_total_floors         float64
# apartment_floor               float64
# apartment_rooms               float64
# apartment_bedrooms            float64
# apartment_bathrooms           float64
# apartment_total_area           object
# apartment_living_area          object
# price_in_USD                  float64
# image                          object
# url                            object
# dtype: object

# %%
df.isna().sum()
# Out:
# title                              0
# country                          130
# location                         131
# building_construction_year     82817
# building_total_floors          79312
# apartment_floor                92944
# apartment_rooms                73358
# apartment_bedrooms            110554
# apartment_bathrooms            91563
# apartment_total_area            5740
# apartment_living_area         119824
# price_in_USD                    2575
# image                              0
# url                                0
# dtype: int64

# %%
df = df.dropna(subset=["country", "location", "apartment_rooms", "apartment_total_area", "price_in_USD" ])

# %%
df["country"].unique()
# Out:
# array(['Turkey', 'Georgia', 'Montenegro', 'Northern Cyprus', 'UAE',
#        'Czech Republic', 'Uzbekistan', 'Thailand', 'Belarus', 'Serbia',
#        'Greece', 'Italy', 'Hungary', 'Finland', 'Russia', 'Poland',
#        'Lithuania', 'Austria', 'Spain', 'United States', 'Croatia',
#        'Latvia', 'Portugal', 'Cyprus', 'Australia', 'Armenia',
#        'Indonesia'], dtype=object)

# %%
df.groupby("country")["title"].count()
# Out:
# country
# Armenia              108
# Australia              1
# Austria              188
# Belarus             8553
# Croatia              839
# Cyprus                47
# Czech Republic      1209
# Finland              390
# Georgia             3171
# Greece              2498
# Hungary             5841
# Indonesia             69
# Italy               1051
# Latvia              1685
# Lithuania           1086
# Montenegro          1739
# Northern Cyprus      516
# Poland              1141
# Portugal             343
# Russia             16575
# Serbia               104
# Spain               2352
# Thailand             748
# Turkey             18230
# UAE                 2179
# United States        198
# Uzbekistan          1773
# Name: title, dtype: int64
